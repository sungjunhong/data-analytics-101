# %% [markdown]
# # 열한번째마당. 마크다운으로 데이터 분석 보고서 만들기

# %% [markdown]
# ## **신뢰할 수 있는 데이터 분석 보고서 만들기**

# %% [markdown]
# * 데이터 분석 결과를 잘 전달하려면 코드와 결과물, 설명글이 잘 어우러진 보고서 작성이 필요
# * `마크다운(markdown)`을 활용하면 데이터를 분석하는 과정을 담은 보고서를 쉽게 만들 수 있으며, 분석 과정과 결과를 자세하게 기술할 수 있어 재현성을 갖춘 데이터 분석 보고서 작성 가능

# %% [markdown]
# ### 마크다운 기본 문법

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [raw]
# 문자 앞뒤에 *특수문자*를 넣으면 기울임체가 됩니다.
#
# 문자 앞뒤에 **특수문자**를 넣으면 **강조체**가 됩니다.
#
# 문자 앞뒤에 ~~특수문자~~를 넣으면 취소선을 만듭니다.
#
# 문자 앞뒤에 [특수문자](http://www.google.com/search?q=special+character)를 넣으면 하이퍼링크를 만듭니다.
#
# * 문자 앞뒤에 백틱(`)을 입력하면 문자에 `음영`을 넣습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1단계 제목
# ## 2단계 제목
# ### 3단계 제목
# #### 4단계 제목
# ##### 5단계 제목

# %% [markdown]
# ## **데이터 분석 보고서 만들기**

# %% [markdown]
# #### 마크다운 보고서
#
# 마크다운 문법으로 코드를 작성해 [HTML](https://ko.wikipedia.org/wiki/HTML)로 변환할 수 있습니다. 마크다운을 이용하면 분석 과정과 결과를 자세하게 기술할 수 있어서 **재현 가능성**을 갖춘 *데이터 분석 보고서*를 만들 수 있습니다.
#
# ##### 마크다운 문법 예제
#
# 코드와 코드 실행 결과물을 보고서에 함께 출력합니다.

# %%
import pandas as pd
df = pd.read_csv('mpg.csv')
df['drv'].value_counts()

# %%
import seaborn as sns
sns.countplot(data = df, x = 'drv')

# %% [markdown]
# # See also:

# %% [markdown]
# * [Markdown 가이드](/notebooks/markdown_guide.ipynb)
